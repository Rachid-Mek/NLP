# %%
import pandas as pd
import gensim
from gensim import corpora
from gensim.models import TfidfModel, Phrases
import nltk
from nltk.corpus import reuters
import spacy

# %%
nlp = spacy.load("en_core_web_sm")
corpus = reuters.sents(categories=["coffee"])

# Convert the corpus to a list of sentences
example_text = [" ".join(sent) for sent in corpus]

#preprocessing of the text
texts = []
for document in example_text:
    doc = nlp(document)
    text = [token.lemma_ for token in doc if not token.is_stop and not token.is_punct]
    texts.append(text)

# Create a dictionary representation of the documents.
dictionary = corpora.Dictionary(texts)
corpus_bow = [dictionary.doc2bow(text) for text in texts]

# Create a TF-IDF model
tfidf_model = TfidfModel(corpus_bow)
corpus_tfidf = tfidf_model[corpus_bow]

bigram = Phrases(texts)
texts_with_bigrams = [bigram[line] for line in texts]

trigram = Phrases(texts_with_bigrams)
texts_with_trigrams = [trigram[line] for line in texts_with_bigrams]

print("Bigrams:")
for text in texts_with_bigrams:
        for word in text:
               if word.count("_") == 1:
                print(word)
# Out:
# Bigrams:
# calendar_1987
# tell_Reuters
# palm_oil
# palm_oil
# palm_oil
# Trade_Minister
# Indonesia_s
# Trade_Minister
# world_s
# latin_american
# mln_dlrs
# 1_5
# billion_dlrs
# cent_lb
# Jorge_Cardenas
# National_Coffee
# Growers_Federation
# mln_60
# kg_bag
# New_York
# cent_lb
# export_registration
# marketing_policy
# Gilberto_Arango
# private_exporter
# tell_Reuters
# Colombia_open
# private_exporter
# 000_bag
# 000_bag
# NIL_SAO
# NIL_SAO
# 000_bag
# 000_bag
# mln_dlrs
# 5_mln
# 1_5
# billion_dlrs
# mln_dlrs
# 5_mln
# 1_5
# billion_dlrs
# Uganda_s
# trade_source
# Uganda_s
# mln_dlrs
# source_say
# mln_dlrs
# 60_kg
# Uganda_s
# export_earning
# mln_bag
# end_September
# 25_pct
# U_s
# u_s
# green_coffee
# 60_kilo
# 000_bag
# 000_bag
# end_March
# calendar_1987
# 000_bag
# 000_bag
# Colombia_open
# private_exporter
# National_Coffee
# Growers_Federation
# 000_bag
# International_Coffee
# Organisation_ICO
# central_american
# produce_country
# export_quota
# Costa_Rica
# source_say
# International_Coffee
# Organization_ICO
# Coffee_Institute
# mln_60
# kilo_bag
# export_quota
# new_formula
# International_Coffee
# Organization_ICO
# tell_Reuters
# new_formula
# world_s
# Brazil_s
# end_week
# quota_share
# produce_country
# source_say
# end_week
# International_Coffee
# quota_suspend
# U_s
# U_s
# Brazilian_Coffee
# new_formula
# Brazilian_Coffee
# Institute_IBC
# 000_bag
# tell_Reuters
# mln_dlrs
# mln_dlrs
# new_formula
# International_Coffee
# Organization_ICO
# van_Horick
# new_formula
# world_s
# van_Horick
# van_Horick
# quota_suspend
# van_Horick
# new_formula
# Costa_Rica
# Ivory_Coast
# El_Salvador
# quota_share
# van_Horick
# quota_distribution
# van_Horick
# Brazil_s
# van_Horick
# U_s
# u_s
# producer_consumer
# u_s
# International_Coffee
# Jorge_Cardenas
# u_s
# new_formula
# van_Horick
# new_formula
# export_quota
# U_s
# objective_criterion
# 1987_88
# 1987_88
# Brazil_s
# mln_bag
# mln_bag
# mln_bag
# mln_bag
# 1986_87
# Ivory_Coast
# 1986_87
# 1987_88
# trade_source
# early_month
# 1986_87
# 000_tonne
# 1985_86
# 1986_87
# Ivory_Coast
# 000_tonne
# 1985_86
# U_s
# 1986_87
# Ivory_Coast
# mln_bag
# mln_bag
# foreign_exchange
# export_earning
# foreign_exchange
# export_earning
# export_earning
# source_say
# foreign_exchange
# export_quota
# Brazilian_Coffee
# president_Jorio
# Dauster_say
# export_quota
# United_States
# reach_agreement
# quota_distribution
# International_Coffee
# Organisation_ICO
# Dauster_say
# Brazil_s
# mln_bag
# u_s
# U_s
# trade_source
# National_Coffee
# U_s
# U_s
# U_s
# trade_source
# u_s
# u_s
# non_member
# non_member
# U_s
# green_coffee
# non_member
# non_member
# U_s
# Brazilian_Coffee
# Institute_IBC
# tell_Reuters
# Jorio_Dauster
# National_Coffee
# export_quota
# 25_pct
# April_1
# September_30
# contribution_quota
# contribution_quota
# export_registration
# trade_source
# end_week
# 25_pct
# export_quota
# export_quota
# International_Coffee
# Organization_ICO
# export_quota
# early_month
# market_situation
# 1987_88
# 1986_87
# Colombia_open
# export_registration
# trade_source
# Uganda_s
# 000_tonne
# tell_reporter
# world_s
# 000_tonne
# Uganda_s
# mln_60
# kg_bag
# export_quota
# International_Coffee
# U_s
# New_York
# Coffee_Sugar
# Cocoa_Exchange
# Jorge_Cardenas
# International_Coffee
# Organization_ICO
# ICO_executive
# March_31
# council_session
# export_quota
# early_month
# export_quota
# suspend_February
# National_Coffee
# United_States
# Brazil_s
# Jorio_Dauster
# market_situation
# mln_60
# kg_bag
# world_market
# foreign_exchange
# Kenya_s
# foreign_exchange
# crude_oil
# countertrade_deal
# foreign_exchange
# crude_oil
# trade_source
# tell_Reuters
# trade_source
# countertrade_deal
# billion_dlrs
# source_say
# billion_dlrs
# 1985_86
# end_March
# source_say
# crude_oil
# billion_dlrs
# 1986_87
# 1985_86
# trade_source
# billion_dlrs
# 1985_86
# source_say
# countertrade_deal
# countertrade_deal
# trade_source
# mln_dlrs
# state_run
# 25_pct
# 000_tonne
# trade_source
# 000_tonne
# 000_tonne
# Coffee_Growers
# u_s
# 000_tonne
# countertrade_deal
# foreign_exchange
# crude_oil
# trade_source
# tell_Reuters
# trade_source
# countertrade_deal
# billion_dlrs
# source_say
# billion_dlrs
# 1985_86
# end_March
# source_say
# crude_oil
# billion_dlrs
# 1986_87
# latin_american
# produce_country
# Trade_Minister
# Martinez_Cuenca
# International_Coffee
# Organisation_ICO
# executive_board
# latin_american
# tell_reporter
# price_fall
# fail_agree
# export_quota
# export_quota
# export_quota
# International_Coffee
# year_ago
# price_soar
# central_american
# mln_dlrs
# foreign_exchange
# commodity_agreement
# U_s
# u_s
# green_coffee
# end_March
# 60_kilo
# 000_bag
# 000_bag
# end_March
# calendar_1987
# 000_bag
# 000_bag
# green_coffee
# trade_source
# U_s
# International_Coffee
# Organization_ICO
# export_quota
# U_s
# ICO_talk
# reach_agreement
# export_quota
# U_s
# u_s
# United_States
# executive_board
# International_Coffee
# Organization_ICO
# u_s
# U_s
# ICO_talk
# producer_consumer
# U_s
# objective_criterion
# U_s
# U_s
# ICO_executive
# board_meet
# International_Coffee
# Organization_ICO
# executive_board
# export_quota
# trade_source
# consume_country
# ICO_talk
# producer_consumer
# reach_agreement
# U_s
# delegate_say
# March_31
# market_situation
# Brazilian_Coffee
# president_Jorio
# U_s
# Jorge_Cardenas
# attend_meeting
# council_meeting
# delegate_say
# council_meeting
# September_30
# U_s
# export_quota
# 30_pct
# objective_criterion
# Brazil_s
# latin_american
# Costa_Rica
# Trade_Minister
# Martinez_Cuenca
# tell_reporter
# Brazilian_Coffee
# Institute_IBC
# export_registration
# Jorio_Dauster
# contribution_quota
# contribution_quota
# world_market
# contribution_quota
# source_say
# end_week
# International_Coffee
# Organisation_ICO
# executive_board
# council_meeting
# export_quota
# source_say
# contribution_quota
# 000_tonne
# 1987_88
# end_March
# 000_tonne
# 1986_87
# 1985_86
# export_quota
# International_Coffee
# reach_agreement
# export_quota
# suspend_February
# Brazil_s
# commodity_pact
# non_member
# buffer_stock
# buffer_stock
# non_member
# world_s
# early_month
# buffer_stock
# buffer_stock
# buffer_stock
# International_Coffee
# Organization_ICO
# objective_criterion
# export_quota
# world_s
# quota_share
# 30_pct
# ICO_executive
# board_meeting
# trade_source
# export_quota
# mln_dlrs
# U_s
# u_s
# U_s
# u_s
# commodity_pact
# u_s
# producer_consumer
# U_s
# commodity_agreement
# International_Coffee
# U_s
# consume_country
# u_s
# commodity_agreement
# u_s
# U_s
# commodity_pact
# tell_Reuters
# world_s
# palm_oil
# commodity_pact
# 000_tonne
# tell_Reuters
# producer_consumer
# develop_country
# develop_country
# commodity_agreement
# produce_country
# objective_criterion
# commodity_pact
# buffer_stock
# commodity_pact
# commodity_pact
# market_situation
# Indonesia_s
# tell_Reuters
# commodity_agreement
# Trade_Minister
# Martinez_Cuenca
# commodity_agreement
# Martinez_Cuenca
# tell_Reuters
# consume_country
# export_earning
# develop_country
# International_Coffee
# Organization_ICO
# export_quota
# delegate_say
# export_quota
# producer_consumer
# fail_agree
# export_quota
# U_s
# delegate_say
# tell_reporter
# council_meeting
# quota_share
# 30_pct
# splinter_group
# objective_criterion
# Brazil_s
# 0_mln
# tell_Reuters
# 000_bag
# Coffee_Organization
# 000_bag
# delegate_say
# latin_american
# delegate_say
# fail_agree
# delegate_say
# Coffee_Sugar
# Cocoa_Exchange
# 0_cent
# 0_cent
# 0_cent
# 0_cent
# 0_cent
# 0_cent
# 0_cent
# export_quota
# International_Coffee
# Organization_ICO
# tell_reporter
# ICO_executive
# board_meeting
# Coffee_Organization
# producer_consumer
# export_quota
# council_meeting
# Costa_Rica
# El_Salvador
# Coffee_Sugar
# Cocoa_Exchange
# mln_dlrs
# Teck_Hock
# creditor_bank
# Teck_Hock
# creditor_bank
# Teck_Hock
# Bank_Ltd
# Bank_Ltd
# Bank_Ltd
# International_Coffee
# Organization_ICO
# market_situation
# delegate_say
# ICO_executive
# producer_consumer
# export_quota
# delegate_say
# early_month
# producer_consumer
# delegate_say
# council_session
# Coffee_Organization
# market_situation
# delegate_say
# export_quota
# New_York
# executive_board
# producer_consumer
# Kenya_s
# private_sector
# Kenya_s
# private_sector
# price_fall
# Kenya_s
# Kenya_s
# state_run
# private_sector
# private_sector
# U_s
# 30_pct
# mln_dlrs
# Kenya_s
# private_sector
# Kenya_s
# private_sector
# price_fall
# Kenya_s
# Kenya_s
# state_run
# export_quota
# 1986_87
# International_Coffee
# Organization_ICO
# producer_consumer
# tell_reporter
# Brazil_s
# Brazil_s
# 30_pct
# export_quota
# New_York
# New_York
# delegate_say
# executive_board
# delegate_say
# Brazil_s
# delegate_say
# Brazil_s
# Brazil_s
# International_Coffee
# quota_share
# quota_distribution
# objective_criterion
# council_session
# splinter_group
# quota_share
# delegate_say
# delegate_say
# quota_share
# U_s
# quota_share
# objective_criterion
# Brazil_s
# export_registration
# council_session
# market_situation
# delegate_say
# ICO_executive
# board_meeting
# delegate_say
# International_Coffee
# Organization_ICO
# reach_agreement
# export_quota
# tell_Reuters
# special_meeting
# ICO_executive
# board_meet
# April_1
# produce_country
# International_Coffee
# Organization_ICO
# reach_agreement
# export_quota
# Gilberto_Arango
# exporter_association
# tell_Reuters
# special_meeting
# fail_agree
# export_quota
# year_ago
# price_soar
# short_term
# Brazil_s
# central_american
# trade_source
# New_York
# produce_nation
# world_s
# ICO_talk
# International_Coffee
# executive_board
# export_quota
# delegate_say
# market_situation
# council_session
# executive_board
# delegate_say
# New_York
# cent_lb
# International_Coffee
# export_quota
# export_quota
# short_term
# contribution_quota
# export_quota
# cent_lb
# cent_lb
# U_s
# produce_nation
# year_ago
# foreign_debt
# cent_lb
# Brazil_s
# U_s
# mln_bag
# end_September
# price_fall
# short_term
# Coffee_Sugar
# Cocoa_Exchange
# price_fall
# International_Coffee
# reach_agreement
# executive_board
# export_quota
# executive_board
# export_quota
# New_York
# produce_nation
# U_s
# price_fall
# New_York
# U_s
# U_s
# New_York
# U_s
# U_s
# New_York
# Coffee_Sugar
# Cocoa_Exchange
# price_fall
# International_Coffee
# reach_agreement
# executive_board
# export_quota
# executive_board
# export_quota
# New_York
# produce_nation
# U_s
# price_fall
# New_York
# U_s
# U_s
# 5_mln
# International_Coffee
# Organisation_ICO
# export_quota
# tell_Reuters
# 30_pct
# non_member
# 000_tonne
# 1986_87
# Kenya_s
# trade_source
# source_say
# International_Coffee
# 1986_87
# mln_bag
# 1986_87
# 1985_86
# 1986_87
# 50_NA
# 50_NA
# Robusta_Cherry
# NA_Robusta
# 50_NA
# 50_NA
# Robusta_Cherry
# 50_NA
# Robusta_Cherry
# NA_Robusta
# 1985_86
# Robusta_Cherry
# 50_NA
# tell_Reuters
# export_quota
# International_Coffee
# Organisation_ICO
# mln_dlrs
# mln_dlrs
# trade_source
# International_Coffee
# Organization_ICO
# export_quota
# tell_reporter
# International_Coffee
# Organization_ICO
# executive_board
# Costa_Rica
# El_Salvador
# board_meeting
# delegate_say
# 1_5
# delegate_say
# green_coffee
# Ivory_Coast
# 0_MM
# 0_MM
# 0_MM
# 0_MM
# NIL_SAO
# price_fall
# export_quota
# International_Coffee
# Organization_ICO
# consume_country
# export_quota
# New_York
# cent_lb
# ICO_talk
# cent_lb
# cent_lb
# quota_suspend
# Brazilian_Coffee
# Institute_IBC
# Jorio_Dauster
# Dauster_say
# Dauster_say
# trade_source
# mln_bag
# producer_consumer
# objective_criterion
# quota_share
# Dauster_say
# export_quota
# Dauster_say
# non_member
# objective_criterion
# Dauster_say
# delegate_say
# delegate_say
# buffer_stock
# delegate_say
# price_fall
# ICO_executive
# board_meet
# April_1
# producer_consumer
# delegate_say
# board_meet
# latin_american
# Brazil_s
# export_registration
# Brazilian_Coffee
# Institute_IBC
# export_registration
# 0_mln
# mln_60
# kilo_bag
# 000_bag
# 0_mln
# mln_bag
# Brazilian_Coffee
# mln_60
# kilo_bag
# green_coffee
# non_member
# International_Coffee
# Brazilian_Coffee
# Institute_IBC
# export_registration
# mln_bag
# 60_kilo
# Brazilian_Coffee
# Institute_IBC
# export_registration
# International_Coffee
# export_quota
# tell_Reuters
# 1986_87
# end_September
# 000_tonne
# 1985_86
# mln_bag
# 60_kg
# 1986_87
# mln_bag
# NIL_SAO
# NIL_SAO
# 0_MM
# u_s
# New_York
# New_York
# New_York
# Coffee_Sugar
# Cocoa_Exchange
# New_York
# New_York
# U_s
# International_Coffee
# Organization_ICO
# United_States
# u_s
# objective_criterion
# U_s
# u_s
# tell_Reuters
# United_States
# United_States
# objective_criterion
# ICO_talk
# export_quota
# world_s
# U_s
# u_s
# producer_consumer
# u_s
# U_s
# splinter_group
# latin_american
# U_s
# U_s
# U_s
# U_s
# u_s
# U_s
# El_Salvador
# objective_criterion
# Costa_Rica
# splinter_group
# objective_criterion
# United_States
# splinter_group
# objective_criterion
# U_s
# consume_country
# U_s
# objective_criterion
# U_s
# U_s
# source_say
# Ivory_Coast
# U_s
# U_s
# Brazil_s
# u_s
# Brazil_s
# U_s
# u_s
# International_Coffee
# Organisation_ICO
# export_quota
# U_s
# tell_Reuters
# U_s
# export_quota
# U_s
# latin_american
# tell_Reuters
# mln_dlrs
# mln_dlrs
# 5_mln
# 5_mln
# 1985_86
# end_September
# export_quota
# International_Coffee
# tell_Reuters
# Brazil_s
# 25_pct
# 30_pct
# mln_bag
# mln_bag
# Brazil_s
# 5_mln
# 0_mln
# 5_mln
# green_coffee
# mln_bag
# green_coffee
# mln_bag
# non_member
# mln_bag
# mln_bag
# 0_mln
# mln_bag
# Brazilian_Coffee
# mln_bag
# foreign_debt
# 1_5
# billion_dlrs
# latin_american
# foreign_debt
# billion_dlrs
# price_fall
# Ivory_Coast
# International_Coffee
# Organisation_ICO
# producer_consumer
# export_quota
# tell_reporter
# billion_dlrs
# Ivory_Coast
# world_market
# world_s
# Ivory_Coast
# Coffee_Organisation
# world_market
# state_run
# Ivory_Coast
# mln_dlrs
# Ivory_Coast
# Ivory_Coast
# creditor_bank
# Teck_Hock
# creditor_bank
# source_say
# mln_dlrs
# source_say
# Teck_Hock
# creditor_bank
# creditor_bank
# Teck_Hock
# creditor_bank
# Teck_Hock
# Bank_Ltd
# Bank_Ltd
# Bank_Ltd
# International_Coffee
# export_quota
# Brazilian_Coffee
# Institute_IBC
# Jorio_Dauster
# 5_mln
# 5_mln
# world_market
# 5_mln
# Dauster_say
# short_term
# Dauster_say
# Dauster_say
# mln_bag
# Brazil_s
# export_quota
# Brazil_s
# produce_country
# Dauster_say
# Dauster_say
# export_registration
# 5_mln
# mln_bag
# mln_bag
# export_quota
# special_meeting
# International_Coffee
# Organization_ICO
# delegate_say
# export_quota
# International_Coffee
# year_ago
# price_soar
# Brazil_s
# world_s
# producer_consumer
# quota_distribution
# delegate_say
# produce_country
# contact_group
# producer_consumer
# Costa_Rica
# April_1
# quota_share
# September_30
# delegate_say
# 30_pct
# Ivory_Coast
# consume_country
# quota_share
# quota_distribution
# quota_share
# delegate_say
# source_say
# Indonesia_s
# calendar_1987
# U_s
# Indonesia_s
# Indonesia_s
# 1_5
# calendar_1987
# palm_oil
# palm_oil
# crude_oil
# palm_oil
# 000_tonne
# 000_tonne
# 1987_88
# 1986_87
# Indonesia_s
# foreign_debt
# latin_american
# foreign_debt
# billion_dlrs
# 1_5
# billion_dlrs
# billion_dlrs
# International_Coffee
# Organization_ICO
# export_quota
# delegate_say
# producer_consumer
# special_meeting
# delegate_say
# delegate_say
# export_quota
# year_ago
# price_soar
# Brazil_s
# world_s
# Brazil_s
# billion_dlrs
# foreign_debt
# world_s
# foreign_exchange
# world_market
# tell_Reuters
# world_market
# foreign_exchange
# billion_dlrs
# world_s
# International_Coffee
# Organization_ICO
# export_quota
# producer_consumer
# New_York
# cent_lb
# Brazilian_Coffee
# Jorio_Dauster
# ICO_talk
# export_quota
# foreign_debt
# u_s
# U_s
# U_s
# U_s
# Brazil_s
# 1986_87
# world_market
# Brazil_s
# International_Coffee
# Organisation_ICO
# source_say
# mln_60
# kilo_bag
# Costa_Rica
# International_Coffee
# export_quota
# Coffee_Institute
# Costa_Rica
# produce_nation
# United_States
# export_quota
# produce_nation
# International_Coffee
# green_coffee
# trade_source
# Colombia_open
# export_registration
# Brazilian_Coffee
# Jorio_Dauster
# Indonesia_s
# calendar_1987
# 1987_88
# U_s
# 1986_87
# mln_bag
# mln_bag
# 1985_86
# 1987_88
# mln_bag
# 0_mln
# 1986_87
# 1985_86
# mln_bag
# 1987_88
# 1986_87
# International_Coffee
# 000_tonne
# 000_tonne
# 000_tonne
# 000_tonne
# 000_tonne
# calendar_1987
# Indonesia_s
# 000_tonne
# calendar_1987
# 000_tonne
# 000_tonne
# world_market
# ICO_talk
# export_quota
# International_Coffee
# Organization_ICO
# council_session
# contact_group
# delegate_say
# 60_kg
# National_Coffee
# Growers_Federation
# state_run
# producer_consumer
# fail_agree
# world_s
# International_Coffee
# Organisation_ICO
# end_week
# quota_suspend
# mln_dlrs
# foreign_exchange
# 0_mln
# mln_60
# kilo_bag
# 25_pct
# 1986_87
# mln_bag
# export_quota
# 1_5
# 0_MM
# 0_MM
# 0_MM
# NIL_SAO
# Brazilian_Coffee
# Institute_IBC
# mln_bag
# mln_bag
# 1_5
# mln_bag
# 30_pct
# 30_pct
# short_term
# Brazil_s
# 000_bag
# mln_bag
# 000_bag
# source_say
# Brazil_s
# 000_bag
# International_Coffee
# council_meeting
# producer_consumer
# export_quota
# delegate_say
# contact_group
# April_1
# delegate_say
# Indonesia_s
# 1986_87
# end_September
# 000_tonne
# tell_Reuters
# Indonesia_s
# 1985_86
# 000_tonne
# 000_tonne
# 000_tonne
# 1985_86
# u_s
# 30_pct
# 000_tonne
# export_quota
# tell_Reuters
# world_s
# produce_country
# Costa_Rica
# International_Coffee
# ICO_talk
# latin_american
# world_s
# U_s
# ICO_executive
# board_meeting
# April_1
# U_s
# Indonesia_s
# 30_pct
# export_quota
# suspend_February
# producer_consumer
# U_s
# Indonesia_s
# 1986_87
# end_September
# 000_tonne
# 000_tonne
# 000_tonne
# 000_tonne
# 000_tonne
# buffer_stock
# buffer_stock
# foreign_exchange
# International_Coffee
# Organization_ICO
# produce_country
# export_quota
# April_1
# September_30
# quota_distribution
# delegate_say
# April_1
# mln_bag
# contact_group
# delegate_say
# Brazilian_Coffee
# Institute_IBC
# end_week
# trade_source
# president_Jorio
# Brazil_s
# early_month
# International_Coffee
# Organization_ICO
# export_quota
# National_Coffee
# tell_reporter
# ICO_talk
# 5_mln
# 60_kilo
# export_registration
# contribution_quota
# price_fall
# world_market
# mln_bag
# 0_mln
# Brazil_s
# foreign_exchange
# source_say
# Brazil_s
# mln_bag
# 1_5
# 0_mln
# non_member
# 5_mln
# mln_bag
# Dauster_say
# mln_bag
# mln_bag
# 0_mln
# source_say
# export_earning
# Brazil_s
# mln_bag
# Brazil_s
# ICO_talk
# International_Coffee
# Organization_ICO
# executive_board
# March_31
# April_1
# export_registration
# export_registration
# New_York
# private_exporter
# export_registration
# International_Coffee
# Organisation_ICO
# export_quota
# short_term
# ICO_talk
# export_quota
# suspend_February
# mln_bag
# 60_kilo
# 5_mln
# 5_mln
# 1985_86
# end_September
# Jorge_Cardenas
# marketing_policy
# trade_source
# Brazil_s
# end_week
# Brazil_s
# Uganda_s
# export_earning
# Colombia_open
# export_registration
# National_Coffee
# Growers_Federation
# Gilberto_Arango
# private_exporter
# tell_Reuters
# International_Coffee
# producer_consumer
# fail_agree
# export_quota
# Colombia_open
# export_registration
# Gilberto_Arango
# private_exporter
# tell_Reuters
# export_registration
# National_Coffee
# Growers_Federation
# private_exporter
# 000_bag
# 60_kilo
# marketing_policy
# export_registration
# marketing_policy
# export_registration
# private_exporter
# U_s
# u_s
# green_coffee
# end_March
# 60_kilo
# 000_bag
# 000_bag
# calendar_1987
# 000_bag
# 000_bag
# marketing_policy
# Gilberto_Arango
# exporter_association
# world_s
# International_Coffee
# Organization_ICO
# export_quota
# ICO_talk
# export_quota
# suspend_February
# export_registration
# world_market
# export_registration
# export_registration
# marketing_policy
# mln_60
# kilo_bag
# mln_bag
# 5_mln
# 1985_86
# end_September
# 1986_87
# 5_mln
# National_Coffee
# Growers_Federation
# 5_mln
# U_s
# 5_mln
# 5_mln
# ICO_talk
# Jorge_Cardenas
# United_States
# export_quota
# foreign_debt
# export_earning
# develop_country
# develop_country
# develop_country
# commodity_agreement
# International_Coffee
# export_quota
# foreign_exchange
# foreign_exchange
# billion_dlrs
# foreign_debt
# billion_dlrs
# billion_dlrs
# develop_country
# special_meeting
# International_Coffee
# Organization_ICO
# export_quota
# delegate_say
# April_1
# Brazil_s
# delegate_say
# delegate_say
# council_meeting
# delegate_say
# tell_Reuters
# latin_american
# International_Coffee
# attend_meeting
# central_american
# central_american
# Costa_Rica
# Brazil_s
# export_quota
# Brazilian_Coffee
# Institute_IBC
# president_Jorio
# Dauster_say
# attend_meeting
# tell_Reuters
# central_american
# market_situation
# 000_tonne
# 1987_88
# Coffee_Growers
# 000_tonne
# United_States
# attend_meeting
# produce_country
# National_Coffee
# Growers_Federation
# tell_Reuters
# central_american
# produce_country
# market_situation
# International_Coffee
# Gilberto_Arango
# exporter_association
# export_quota
# International_Coffee
# executive_board
# March_31
# source_say
# 000_tonne
# source_say
# source_say
# 000_tonne
# 000_tonne
# source_say
# Coffee_Sugar
# Cocoa_Exchange
# latin_american
# International_Coffee
# Organisation_ICO
# Martinez_Cuenca
# El_Salvador
# Costa_Rica
# Martinez_Cuenca
# tell_reporter
# mln_dlrs
# International_Coffee
# Organization_ICO
# delegate_say
# splinter_group
# quota_distribution
# delegate_say
# contact_group
# Brazilian_Coffee
# Institute_IBC
# Jorio_Dauster
# tell_Reuters
# contact_group
# Dauster_say
# Jorio_Dauster
# Brazilian_Coffee
# Institute_IBC
# latin_american
# attend_meeting
# latin_american
# Trade_Minister
# Martinez_Cuenca
# export_quota
# El_Salvador
# Costa_Rica
# attend_meeting
# export_quota
# International_Coffee
# export_quota
# Jorio_Dauster
# Brazilian_Coffee
# Indonesia_s
# billion_dlrs
# mln_dlrs
# palm_oil
# world_market
# green_coffee
# trade_source
# Brazil_s
# export_registration
# Colombia_open
# export_registration
# source_say
# end_week
# Costa_Rica
# Uganda_s
# state_run
# trade_source
# mln_dlrs
# Uganda_s
# source_say
# 000_bag
# Uganda_s
# mln_60
# kilo_bag
# 1986_87
# source_say
# source_say
# Uganda_s
# foreign_exchange
# source_say
# Uganda_s
# special_meeting
# International_Coffee
# Organization_ICO
# fail_agree
# export_quota
# delegate_say
# producer_consumer
# quota_distribution
# delegate_say
# export_quota
# International_Coffee
# year_ago
# price_soar
# International_Coffee
# Organization_ICO
# reach_agreement
# export_quota
# trade_source
# cent_lb
# special_meeting
# delegate_say
# International_Coffee
# year_ago
# price_soar
# trade_source
# U_s
# U_s
# objective_criterion
# export_quota
# Brazilian_Coffee
# Institute_IBC
# Jorio_Dauster
# 30_pct
# mln_60
# kilo_bag
# Brazil_s
# delegate_say
# Brazil_s
# export_earning
# produce_country
# billion_dlrs
# ICO_executive
# board_meet
# March_31
# delegate_say
# mln_dlrs
# mln_dlrs
# mln_dlrs
# world_market
# export_quota
# calendar_1987
# billion_dlrs
# Jorge_Cardenas
# National_Coffee
# Growers_Federation
# cent_lb
# mln_dlrs
# mln_60
# kg_bag
# marketing_policy
# Brazil_s
# Brazil_s
# billion_dlrs
# green_coffee
# Brazilian_Coffee
# Institute_IBC
# president_Jorio
# Dauster_say
# ICO_executive
# board_meeting
# New_York
# ICO_executive
# board_meeting
# Dauster_say
# Dauster_say
# board_meeting
# attend_meeting
# Brazilian_Coffee
# Institute_IBC
# president_Jorio
# Dauster_say
# tell_Reuters
# International_Coffee
# early_month
# export_quota
# Dauster_say
# Dauster_say
# El_Salvador
# Costa_Rica
# price_fall
# short_term
# International_Coffee
# Organization_ICO
# export_quota
# price_fall
# cent_lb
# International_Coffee
# cent_lb

# %%
print("\nTrigrams:")
for text in texts_with_trigrams:
        for word in text:
               if word.count("_") == 2:
                print(word)
# Out:
# Trigrams:
# Gilberto_Arango_president
# trade_source_say
# International_Coffee_Agreement
# Brazilian_Coffee_Institute
# International_Coffee_Organization
# trade_source_say
# Brazilian_Coffee_Institute
# trade_source_say
# trade_source_say
# trade_source_say
# International_Coffee_Agreement
# trade_source_say
# trade_source_say
# trade_source_say
# trade_source_say
# trade_source_say
# International_Coffee_Agreement
# suspend_year_ago
# trade_source_say
# U_s_official
# trade_source_say
# Brazilian_Coffee_Institute
# International_Coffee_Organisation
# International_Coffee_Agreement
# U_s_official
# Kenya_s_economy
# Kenya_s_economy
# Kenya_s_economy
# Kenya_s_economy
# Kenya_s_economy
# Kenya_s_economy
# International_Coffee_Agreement
# Gilberto_Arango_president
# suspend_year_ago
# trade_source_say
# International_Coffee_Organization
# International_Coffee_Organization
# International_Coffee_Organization
# International_Coffee_Organization
# trade_source_say
# International_Coffee_Organization
# trade_source_say
# Brazilian_Coffee_Institute
# International_Coffee_Organisation
# International_Coffee_Organisation
# U_s_official
# U_s_official
# U_s_official
# U_s_official
# U_s_official
# U_s_official
# U_s_official
# 5_mln_bag
# 5_mln_bag
# International_Coffee_Agreement
# 5_mln_bag
# 5_mln_bag
# Brazilian_Coffee_Institute
# International_Coffee_Organization
# 5_mln_bag
# 5_mln_bag
# 5_mln_bag
# 5_mln_bag
# International_Coffee_Agreement
# suspend_year_ago
# suspend_year_ago
# Brazilian_Coffee_Institute
# International_Coffee_Organisation
# International_Coffee_Organization
# trade_source_say
# Brazilian_Coffee_Institute
# International_Coffee_Organisation
# International_Coffee_Organization
# trade_source_say
# 5_mln_bag
# 5_mln_bag
# 5_mln_bag
# Gilberto_Arango_president
# International_Coffee_Organisation
# Gilberto_Arango_president
# Gilberto_Arango_president
# 5_mln_bag
# 5_mln_bag
# 5_mln_bag
# International_Coffee_Organisation
# International_Coffee_Organization
# International_Coffee_Organization
# Gilberto_Arango_president
# International_Coffee_Organization
# International_Coffee_Organization
# Brazilian_Coffee_Institute
# trade_source_say
# trade_source_say
# International_Coffee_Agreement
# suspend_year_ago
# trade_source_say
# International_Coffee_Agreement
# suspend_year_ago
# International_Coffee_Organisation
# International_Coffee_Agreement

# %%
df = pd.DataFrame({"text": texts }) # create a dataframe with the results

df["text"] = df["text"].apply(lambda x: ', '.join(x))
df["bigrams"] = texts_with_bigrams[:] # add the bigrams to the dataframe
df["bigrams"] = df["bigrams"].apply(lambda x: ', '.join(x[:3])) # convert the lists to strings and remove brackets
df["trigrams"] = texts_with_trigrams # add the bigrams and trigrams to the dataframe
df["trigrams"] = df["trigrams"].apply(lambda x: ', '.join(x[:2])) # convert the lists to strings and remove brackets
df.head(10)
# Out:
#                                                 text  \
# 0  indonesian, COMMODITY, EXCHANGE, expand, Indon...
# 1  tell, Reuters, telephone, interview, trading, ...
# 2  trade, crude, palm, oil, CPO, refined, palm, o...
# 3  say, question, consider, Trade, Minister, Rach...
# 4  fledgling, exchange, currently, trade, coffee,...
# 5                factor, cautiously, Nainggolan, say
# 6  want, slowly, safely, mistake, undermine, conf...
# 7  physical, rubber, trading, launch, 1985, coffe...
# 8       rubber, contract, trade, fob, month, forward
# 9  robusta, coffee, grade, trade, prompt, deliver...
#
#                               bigrams                 trigrams
# 0     indonesian, COMMODITY, EXCHANGE    indonesian, COMMODITY
# 1  tell_Reuters, telephone, interview  tell_Reuters, telephone
# 2              trade, crude, palm_oil             trade, crude
# 3             say, question, consider            say, question
# 4      fledgling, exchange, currently      fledgling, exchange
# 5      factor, cautiously, Nainggolan       factor, cautiously
# 6                want, slowly, safely             want, slowly
# 7           physical, rubber, trading         physical, rubber
# 8             rubber, contract, trade         rubber, contract
# 9              robusta, coffee, grade          robusta, coffee

# %%
categories = reuters.categories() # get all the categories
categories = pd.DataFrame({"category": categories}) # create a dataframe with the categories
categories
# Out:
#    category
# 0       acq
# 1      alum
# 2    barley
# 3       bop
# 4   carcass
# ..      ...
# 85  veg-oil
# 86    wheat
# 87      wpi
# 88      yen
# 89     zinc
#
# [90 rows x 1 columns]
